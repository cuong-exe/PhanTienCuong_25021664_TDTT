# %% [markdown]
# #

# %%
#Bai1
n = int(input())
print (n * 2)
# Out:
#  1
# 2

# %%
#Bai2
a, b = map(float, input().split())
pi = 3.14
remain_area = a * b - pi * (a/2) * (a/2)
print(f'Diện tích phần còn lại là: {remain_area:.2f}')
# Out:
#  30 60
# Diện tích phần còn lại là: 1093.50

# %%
#Bai3
c = input()
if (len(c) == 1):  
    if (c.islower()): 
        print(c.upper())
    elif (c.isupper()):
        print(c.lower())
    else:
        print("Khong phai la mot ky tu alphabet")
else:
    print("Ban nhap khong phai 1 ky tu!")
# Out:
#  a
# A

# %%
#Bai4
c = input()
if (len(c) == 1):
    if (c.isalpha()):
        print (f'{c} là kí tự alphabet')
    else:
        print (f'{c} không phải là kí tự alphabet')
else:
    print("Ban nhap khong phai 1 ki tu!")
# Out:
#  3
# 3 không phải là kí tự alphabet

# %%
#Bai5
A = input()
if (A == "A"):
    print(f'Không có chữ cái liền trước {A}')
else:
    print(f'Chữ cái thường của chữ cái liên trước {A} là {chr(ord(A) + 32 - 1)}')
# Out:
#  Z
# chu cai thuong lien truoc Z la y

# %%
#Bai6
import math
a, b, c = map(int, input("Nhap vao ba canh cua tam giac").split())
if (a > 0 and b > 0 and c > 0 and a + b > c and a + c > b and b + c > a):
    print("Là 3 cạnh của tam giác")
    p = (a + b + c) / 2
    s = p * (p - a) * (p - b) * (p - c)
    s = s ** 0.5
    #s = math.sqrt(s)
    #s = pow(s, 0.5)
    print (f'Diện tích của tam giác là {s:.1f}')
else:
    print("Không phải là 3 cạnh của tam giác")
# Out:
#  2 3 4
# Là 3 cạnh của tam giác
# Diện tích của tam giác là 2.9

# %%
#Bai7
text = input()
n = len(text)
if (len(text) >= 20):
    print(text[4], text[8], sep = '\n')
else:
    print("Bạn nhập chuỗi chưa đủ độ dài")
# Out:
#  phantiencuong
# t c

# %%
#Bai8

name = input("Ten chu ho: ")
thang_truoc = int(input("Chi so thang truoc: "))
thang_nay = int(input("Chi so thang nay: "))
kwh = thang_nay - thang_truoc
tong_tien = 0
if kwh > 400:
    tong_tien += (kwh - 400) * 3460
    kwh = 400
if kwh > 300:
    tong_tien += (kwh - 300) * 3350
    kwh = 300
if kwh > 200:
    tong_tien += (kwh - 200) * 2998
    kwh = 200
if kwh > 100:
    tong_tien += (kwh - 100) * 2380
    kwh = 100
if kwh > 50:
    tong_tien += (kwh - 50) * 2050
    kwh = 50
if kwh > 0:
    tong_tien += kwh * 1984
    kwh = 0
'''
gia = [1984, 2050, 2380, 2998, 3350, 3460]
muc = [50, 50, 100, 100, 100, 10000]


for g, m in zip(gia, muc):
    so_dien = min(m, kwh)
    kwh = max(kwh - m, 0)
    tong_tien += so_dien * g
'''
tong_tien = tong_tien * 1.08
print(f'Ho va Ten: {name}')
print(f'Tien phai tra la: {tong_tien:.0f}')
# Out:
# Ten chu ho:  Nguyen Hoang Hai
# Chi so thang truoc:  2000
# Chi so thang nay:  2586
# Ho va Ten: Nguyen Hoang Hai
# Tien phai tra la: 1855505

# %%
import builtins
print(dir(builtins))
print(help(len))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'PythonFinalizationError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarni
# ...
